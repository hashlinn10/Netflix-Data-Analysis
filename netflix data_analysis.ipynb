# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn  as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("C:/Users/LENOVO/Downloads/netflix.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data['rating'] = data['rating'].replace({'PG-13':'Teens(13+)','PG':'Older Kids(7+)','TV-MA':'Adults(18+)','TV-14':'Young Adults(16+)',
                           'TV-PG':'Older Kids(7+)Parental Guidance Suggested','TV-Y':'Kids(All)','TV-Y7':'Older Kids(7+)','R':'Adults only',
                           'NC-17':'No One 17 and Under Admitted', 'TV-G':'Kids(All)Suitable for all ages',
                           'TV-Y7-FV':'Older Kids(7+)programming with fantasy violence','NR':'Adults(18+) NotRated',
                           'G':'Kids(All)','UR':'Unrated'})
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data['date_added'] = pd.to_datetime(data['date_added'],errors = 'coerce')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8709 non-null   datetime64[ns]
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 825.8+ KB

# %%
data.describe()
# Out:
#                           date_added  release_year
# count                           8709   8807.000000
# mean   2019-05-23 01:45:29.452290816   2014.180198
# min              2008-01-01 00:00:00   1925.000000
# 25%              2018-04-20 00:00:00   2013.000000
# 50%              2019-07-12 00:00:00   2017.000000
# 75%              2020-08-26 00:00:00   2019.000000
# max              2021-09-25 00:00:00   2021.000000
# std                              NaN      8.819312

# %%
dw = data[data['release_year'] == 1925]

# %%
dw
# Out:
#      show_id     type                              title director cast  \
# 4250   s4251  TV Show  Pioneers: First Women Filmmakers*      NaN  NaN
#
#      country date_added  release_year             rating  duration listed_in  \
# 4250     NaN 2018-12-30          1925  Young Adults(16+)  1 Season  TV Shows
#
#                                             description
# 4250  This collection restores films from women who ...

# %%
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        98
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
data['rating'].unique()
# Out:
# array(['Teens(13+)', 'Adults(18+)', 'Older Kids(7+)', 'Young Adults(16+)',
#        'Older Kids(7+)Parental Guidance Suggested', 'Kids(All)',
#        'Adults only', 'Kids(All)Suitable for all ages',
#        'No One 17 and Under Admitted', '74 min', '84 min', '66 min',
#        'Adults(18+) NotRated', nan,
#        'Older Kids(7+)programming with fantasy violence', 'Unrated'],
#       dtype=object)

# %%
data['rating'].replace(['74 min','84 min','66 min'],np.nan,inplace = True)

# %%
data['rating'].dropna(inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8709 non-null   datetime64[ns]
#  7   release_year  8807 non-null   int64
#  8   rating        8800 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 825.8+ KB

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        98
# release_year       0
# rating             7
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
data['rating'].dropna(inplace = True)

# %%
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        98
# release_year       0
# rating             7
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
m = data[data['type'] == 'Movie']

# %%
m = m.sort_values(by = 'date_added' ,ascending = False).reset_index().drop('index',axis = 1)

# %%
m
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 1        s10  Movie                      The Starling
# 2         s7  Movie  My Little Pony: A New Generation
# 3         s8  Movie                           Sankofa
# 4        s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 6126   s5955  Movie                     Even the Rain
# 6127   s7371  Movie       Mad Ron's Prevues from Hell
# 6128   s5956  Movie                          Splatter
# 6129   s5957  Movie           Just Another Love Story
# 6130   s5958  Movie              To and From New York
#
#                            director  \
# 0                   Kirsten Johnson
# 1                    Theodore Melfi
# 2     Robert Cullen, José Luis Ucha
# 3                      Haile Gerima
# 4               Christian Schwochow
# ...                             ...
# 6126                  Icíar Bollaín
# ...

# %%
m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6131 entries, 0 to 6130
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       6131 non-null   object
#  1   type          6131 non-null   object
#  2   title         6131 non-null   object
#  3   director      5943 non-null   object
#  4   cast          5656 non-null   object
#  5   country       5691 non-null   object
#  6   date_added    6131 non-null   datetime64[ns]
#  7   release_year  6131 non-null   int64
#  8   rating        6126 non-null   object
#  9   duration      6128 non-null   object
#  10  listed_in     6131 non-null   object
#  11  description   6131 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 574.9+ KB

# %%
m['rating'].unique()
# Out:
# array(['Teens(13+)', 'Older Kids(7+)', 'Adults(18+)',
#        'Older Kids(7+)Parental Guidance Suggested', 'Young Adults(16+)',
#        'Kids(All)', 'Adults only', 'Kids(All)Suitable for all ages',
#        'Adults(18+) NotRated', 'Unrated',
#        'Older Kids(7+)programming with fantasy violence',
#        'No One 17 and Under Admitted', nan], dtype=object)

# %%
m['rating'].nunique()
# Out:
# 12

# %%
T = data[data['type'] == 'TV Show']

# %%
T
# Out:
#      show_id     type                  title         director  \
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8795   s8796  TV Show        Yu-Gi-Oh! Arc-V              NaN
# 8796   s8797  TV Show             Yunus Emre              NaN
# 8797   s8798  TV Show              Zak Storm              NaN
# 8800   s8801  TV Show     Zindagi Gulzar Hai              NaN
# 8803   s8804  TV Show            Zombie Dumb              NaN
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %%
T.sort_values(by = 'date_added',ascending = False).reset_index().drop('index',axis = 1)
# Out:
#      show_id     type                                title         director  \
# 0         s2  TV Show                        Blood & Water              NaN
# 1         s6  TV Show                        Midnight Mass    Mike Flanagan
# 2        s11  TV Show  Vendetta: Truth, Lies and The Mafia              NaN
# 3         s9  TV Show        The Great British Baking Show  Andy Devonshire
# 4         s3  TV Show                            Ganglands  Julien Leclercq
# ...      ...      ...                                  ...              ...
# 2671   s8540  TV Show                           The Tudors              NaN
# 2672   s8558  TV Show                        The West Wing              NaN
# 2673   s8685  TV Show                              Vroomiz              NaN
# 2674   s8713  TV Show           Weird Wonders of the World              NaN
# 2675   s8756  TV Show                    Women Behind Bars              NaN
#
# ...

# %%
sns.countplot(x = data['type'],data = data)
plt.show()

# %%
data['type'].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %%
plt.pie(data['type'].value_counts(),labels = ['Movies','TV Show'],shadow = True,startangle =90, explode = (0,0.1),autopct = '%.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1230af51c40>,
# ...
#  [Text(-0.897672126570692, -0.6357552620136555, 'Movies'),
#   Text(0.979278683531664, 0.6935511949239876, 'TV Show')],
#  [Text(-0.4896393417658319, -0.3467755974619939, '70%'),
#   Text(0.571245898726804, 0.4045715303723261, '30%')])

# %%
df = data.copy()

# %%
df['Country'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 df['Country'].unique()
#
# ...

# %%
data['country'].unique()
# Out:
# array(['United States', 'South Africa', nan, 'India',
#        'United States, Ghana, Burkina Faso, United Kingdom, Germany, Ethiopia',
#        'United Kingdom', 'Germany, Czech Republic', 'Mexico', 'Turkey',
#        'Australia', 'United States, India, France', 'Finland',
#        'China, Canada, United States',
#        'South Africa, United States, Japan', 'Nigeria', 'Japan',
#        'Spain, United States', 'France', 'Belgium',
#        'United Kingdom, United States', 'United States, United Kingdom',
#        'France, United States', 'South Korea', 'Spain',
#        'United States, Singapore', 'United Kingdom, Australia, France',
#        'United Kingdom, Australia, France, United States',
#        'United States, Canada', 'Germany, United States',
#        'South Africa, United States', 'United States, Mexico',
#        'United States, Italy, France, Japan',
#        'United States, Italy, Romania, United Kingdom',
#        'Australia, United States', 'Argentina, Venezuela',
# ...

# %%
df = data.copy()

# %%
df['country'].unique()
# Out:
# array(['United States', 'South Africa', nan, 'India',
#        'United States, Ghana, Burkina Faso, United Kingdom, Germany, Ethiopia',
#        'United Kingdom', 'Germany, Czech Republic', 'Mexico', 'Turkey',
#        'Australia', 'United States, India, France', 'Finland',
#        'China, Canada, United States',
#        'South Africa, United States, Japan', 'Nigeria', 'Japan',
#        'Spain, United States', 'France', 'Belgium',
#        'United Kingdom, United States', 'United States, United Kingdom',
#        'France, United States', 'South Korea', 'Spain',
#        'United States, Singapore', 'United Kingdom, Australia, France',
#        'United Kingdom, Australia, France, United States',
#        'United States, Canada', 'Germany, United States',
#        'South Africa, United States', 'United States, Mexico',
#        'United States, Italy, France, Japan',
#        'United States, Italy, Romania, United Kingdom',
#        'Australia, United States', 'Argentina, Venezuela',
# ...

# %%
df['country'] = df['country'].str.split(',').explode('country')
df['country'] = df['country'].str.lstrip()
df.replace([''],np.nan,inplace = True)
df.dropna(subset = ['country'],inplace = True)

# %%
df['country'].unique()
# Out:
# array(['United States', 'South Africa', 'India', 'Ghana', 'Burkina Faso',
#        'United Kingdom', 'Germany', 'Ethiopia', 'Czech Republic',
#        'Mexico', 'Turkey', 'Australia', 'France', 'Finland', 'China',
#        'Canada', 'Japan', 'Nigeria', 'Spain', 'Belgium', 'South Korea',
#        'Singapore', 'Italy', 'Romania', 'Argentina', 'Venezuela',
#        'Hong Kong', 'Russia', 'Ireland', 'Nepal', 'New Zealand', 'Brazil',
#        'Greece', 'Jordan', 'Colombia', 'Switzerland', 'Israel', 'Taiwan',
#        'Bulgaria', 'Algeria', 'Poland', 'Saudi Arabia', 'Thailand',
#        'Indonesia', 'Egypt', 'Denmark', 'Kuwait', 'Netherlands',
#        'Malaysia', 'Vietnam', 'Hungary', 'Sweden', 'Lebanon', 'Syria',
#        'Philippines', 'Iceland', 'United Arab Emirates', 'Norway',
#        'Qatar', 'Mauritius', 'Austria', 'Cameroon', 'Palestine',
#        'Uruguay', 'Kenya', 'Chile', 'Luxembourg', 'Cambodia',
#        'Bangladesh', 'Portugal', 'Cayman Islands', 'Senegal', 'Serbia',
# ...

# %%
df['country'].describe(include = 'object')
# Out:
# count              8041
# unique              108
# top       United States
# freq               2893
# Name: country, dtype: object

# %%
plt.figure(figsize = (10,10))
sns.countplot(x = 'country',data = df,order = df['country'].value_counts().index[:10])
plt.xticks(rotation = 90)
plt.show()

# %%
ds = data.copy()

# %%
ds.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year       rating   duration  \
# 0 2021-09-25          2020   Teens(13+)     90 min
# 1 2021-09-24          2021  Adults(18+)  2 Seasons
# ...

# %%
df['listed_in'].unique()
# Out:
# array(['Documentaries', 'International TV Shows, TV Dramas, TV Mysteries',
#        'International TV Shows, Romantic TV Shows, TV Comedies',
#        'Dramas, Independent Movies, International Movies',
#        'British TV Shows, Reality TV', 'Comedies, Dramas',
#        'Crime TV Shows, Docuseries, International TV Shows',
#        'Crime TV Shows, International TV Shows, TV Action & Adventure',
#        'Dramas, International Movies',
#        'Children & Family Movies, Comedies',
#        'British TV Shows, Crime TV Shows, Docuseries',
#        'Crime TV Shows, Spanish-Language TV Shows, TV Dramas',
#        'Thrillers',
#        'International TV Shows, TV Action & Adventure, TV Dramas',
#        'Children & Family Movies', 'Comedies', 'TV Comedies',
#        'International TV Shows, TV Dramas, TV Thrillers', "Kids' TV",
#        'Dramas, International Movies, Thrillers',
#        'Action & Adventure, Dramas, International Movies',
# ...

# %%
df['listed_in'].unique()
# Out:
# array(['Documentaries', 'International TV Shows, TV Dramas, TV Mysteries',
#        'International TV Shows, Romantic TV Shows, TV Comedies',
#        'Dramas, Independent Movies, International Movies',
#        'British TV Shows, Reality TV', 'Comedies, Dramas',
#        'Crime TV Shows, Docuseries, International TV Shows',
#        'Crime TV Shows, International TV Shows, TV Action & Adventure',
#        'Dramas, International Movies',
#        'Children & Family Movies, Comedies',
#        'British TV Shows, Crime TV Shows, Docuseries',
#        'Crime TV Shows, Spanish-Language TV Shows, TV Dramas',
#        'Thrillers',
#        'International TV Shows, TV Action & Adventure, TV Dramas',
#        'Children & Family Movies', 'Comedies', 'TV Comedies',
#        'International TV Shows, TV Dramas, TV Thrillers', "Kids' TV",
#        'Dramas, International Movies, Thrillers',
#        'Action & Adventure, Dramas, International Movies',
# ...

# %%
dm = data.copy()
dm['listed_in'] = dm['listed_in'].str.strip(',').explode('listed_in')
dm['listed_in'] = dm['listed_in'].str.lstrip()
dm.replace([''],np.nan,inplace = True)
dm.dropna(subset = ['listed_in'],inplace = True)
dm
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
ds
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
ds
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
dk = data.copy()
dk['listed_in'] = dk['listed_in'].str.strip(',').explode('listed_in')
dk['listed_in'] = dk['listed_in'].str.lstrip()
dk.replace([''],np.nan,inplace = True)
dk.dropna(subset = ['listed_in'],inplace = True)
dk
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
dk['listed_in'].nunique()
# Out:
# 514

# %%
dk
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
dm = data.copy()
dm['listed_in'] = dm['listed_in'].str.split(',').explode('listed_in')
dm['listed_in'] = dm['listed_in'].str.lstrip()
dm.replace([''],np.nan,inplace = True)
dm.dropna(subset = ['listed_in'],inplace = True)
dm
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
dm['listed_in'].nunique()
# Out:
# 42

# %%
dm['listed_in'].value_counts()
# Out:
# listed_in
# International Movies            1231
# Dramas                          1029
# Comedies                         761
# International TV Shows           725
# TV Dramas                        409
# Action & Adventure               346
# TV Comedies                      322
# Children & Family Movies         313
# Romantic Movies                  303
# Documentaries                    278
# Independent Movies               259
# Thrillers                        255
# Crime TV Shows                   250
# Kids' TV                         248
# Romantic TV Shows                189
# Docuseries                       187
# Music & Musicals                 159
# Reality TV                       157
# Horror Movies                    125
# Anime Series                     120
# TV Action & Adventure            112
# Stand-Up Comedy                  111
# Spanish-Language TV Shows        108
# British TV Shows                  90
# Korean TV Shows                   78
# ...

# %%
plt.figure(figsize = (15,5))
set = sns.countplot(x = dm['listed_in'],order = dm['listed_in'].value_counts(ascending = False).index)
set.set_xticklabels(set.get_xticklabels(),rotation = 90)
plt.show()

# %%
data.groupby('rating')['title'].count().sort_values(ascending = False)
# Out:
# rating
# Adults(18+)                                        3207
# Young Adults(16+)                                  2160
# Older Kids(7+)Parental Guidance Suggested           863
# Adults only                                         799
# Older Kids(7+)                                      621
# Teens(13+)                                          490
# Kids(All)                                           348
# Kids(All)Suitable for all ages                      220
# Adults(18+) NotRated                                 80
# Older Kids(7+)programming with fantasy violence       6
# No One 17 and Under Admitted                          3
# Unrated                                               3
# Name: title, dtype: int64

# %%
plt.figure(figsize(15,5))
chart = sns.countplot(x = 'rating' , data = data , order = data['rating'].value_counts(ascending = False).index([:12])
chart.setxtick_labels(chart.get_xticklabels(),rotation = 90)
plt.show()
# Out:
#   Cell In[197], line 2
#     chart = sns.countplot(x = 'rating' , data = data , order = data['rating'].value_counts(ascending = False).index([:12])
#                                                                                                                      ^
# SyntaxError: invalid syntax

# %%
plt.figure(figsize=(10,5))
chart = sns.countplot(x = 'rating' , data = data , order = data['rating'].value_counts(ascending = False).index[:12])
chart.set_xticklabels(chart.get_xticklabels(),rotation = 90)
plt.show()

# %%
dg = data.copy()

# %%
dg['director']= dg['director'].str.split(',').explode('director')
dg['director'] = dg['director'].str.lstrip()
dg.replace([''],np.nan,inplace = True)
dg.dropna(subset = ['director'],inplace = True)

# %%
dg['director'].nunique()
# Out:
# 4564

# %%
dg['director'].describe(include = 'object')
# Out:
# count              6304
# unique             4564
# top       Rajiv Chilaka
# freq                 22
# Name: director, dtype: object

# %%
dg
# Out:
#      show_id     type                             title            director  \
# 0         s1    Movie              Dick Johnson Is Dead     Kirsten Johnson
# 2         s3  TV Show                         Ganglands     Julien Leclercq
# 5         s6  TV Show                     Midnight Mass       Mike Flanagan
# 6         s7    Movie  My Little Pony: A New Generation       Robert Cullen
# 7         s8    Movie                           Sankofa      José Luis Ucha
# ...      ...      ...                               ...                 ...
# 8802   s8803    Movie                            Zodiac      Akiva Goldsman
# 8803   s8804  TV Show                       Zombie Dumb    Arjun Gourisaria
# 8804   s8805    Movie                        Zombieland       Moinak Biswas
# 8805   s8806    Movie                              Zoom    Chatchai Katenut
# 8806   s8807    Movie                            Zubaan  Manussa Vorasingha
#
# ...

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
dk = data.copy()

# %%
dk
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
dk['director']
# Out:
# 0       Kirsten Johnson
# 1                   NaN
# 2       Julien Leclercq
# 3                   NaN
# 4                   NaN
#              ...
# 8802      David Fincher
# 8803                NaN
# 8804    Ruben Fleischer
# 8805       Peter Hewitt
# 8806        Mozez Singh
# Name: director, Length: 8807, dtype: object

# %%
dk['director'].describe()
# Out:
# count              6173
# unique             4528
# top       Rajiv Chilaka
# freq                 19
# Name: director, dtype: object

# %%
dk['director']= dk['director'].str.split(',').explode('director')
dk['director'] = dk['director'].str.lstrip()
dk.replace([''],np.nan,inplace = True)
dk.dropna(subset = ['director'],inplace = True)

# %%
dk
# Out:
#      show_id     type                             title            director  \
# 0         s1    Movie              Dick Johnson Is Dead     Kirsten Johnson
# 2         s3  TV Show                         Ganglands     Julien Leclercq
# 5         s6  TV Show                     Midnight Mass       Mike Flanagan
# 6         s7    Movie  My Little Pony: A New Generation       Robert Cullen
# 7         s8    Movie                           Sankofa      José Luis Ucha
# ...      ...      ...                               ...                 ...
# 8802   s8803    Movie                            Zodiac      Akiva Goldsman
# 8803   s8804  TV Show                       Zombie Dumb    Arjun Gourisaria
# 8804   s8805    Movie                        Zombieland       Moinak Biswas
# 8805   s8806    Movie                              Zoom    Chatchai Katenut
# 8806   s8807    Movie                            Zubaan  Manussa Vorasingha
#
# ...

# %%
dg.groupby('director')['title'].count().sort_values(ascending = False).head(14)
# Out:
# director
# Rajiv Chilaka          22
# Jan Suter              21
# Raúl Campos            19
# Marcus Raboy           16
# Suhas Kadav            16
# Jay Karas              15
# Youssef Chahine        12
# Jay Chapman            12
# Cathy Garcia-Molina    12
# Martin Scorsese        10
# Shannon Hartman         9
# David Dhawan            9
# Steven Spielberg        9
# Don Michael Paul        8
# Name: title, dtype: int64

# %%
plt.figure(figsize = (15,10))
dr = sns.countplot(x = 'director',data = dk,order = dk['director'].value_counts(ascending = False).index[:12])
dr.set_xticklabels(dr.get_xticklabels(),rotation = 90)
plt.show()

# %%
T
# Out:
#      show_id     type                  title         director  \
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8795   s8796  TV Show        Yu-Gi-Oh! Arc-V              NaN
# 8796   s8797  TV Show             Yunus Emre              NaN
# 8797   s8798  TV Show              Zak Storm              NaN
# 8800   s8801  TV Show     Zindagi Gulzar Hai              NaN
# 8803   s8804  TV Show            Zombie Dumb              NaN
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %%
t = T.assign(director = T['director'].str.split(',')).explode('director')
t['director'] = t['director'].str.lstrip()
t.dropna(subset = ['director'],inplace = True)

# %%
t
# Out:
#      show_id     type                                              title  \
# 2         s3  TV Show                                          Ganglands
# 5         s6  TV Show                                      Midnight Mass
# 8         s9  TV Show                      The Great British Baking Show
# 11       s12  TV Show                                   Bangkok Breaking
# 20       s21  TV Show    Monsters Inside: The 24 Faces of Billy Milligan
# ...      ...      ...                                                ...
# 8293   s8294  TV Show                                           The Fear
# 8302   s8303  TV Show                                           The Five
# 8549   s8550  TV Show  The Vietnam War: A Film by Ken Burns and Lynn ...
# 8549   s8550  TV Show  The Vietnam War: A Film by Ken Burns and Lynn ...
# 8599   s8600  TV Show                                    Toast of London
#
#                director                                               cast  \
# ...

# %%
t['director'].value_counts(ascending = False)
# Out:
# director
# Alastair Fothergill      3
# Ken Burns                3
# Jung-ah Im               2
# Gautham Vasudev Menon    2
# Iginio Straffi           2
#                         ..
# Jesse Vile               1
# Ellena Wood              1
# Picky Talarico           1
# Pedro Waddington         1
# Michael Cumming          1
# Name: count, Length: 299, dtype: int64

# %%
plt.figure(figsize = (10,5))
x= sns.countplot(x = 'director',data = t , order = t['director'].value_counts().index[:10])
plt.xticks(rotation = 90)
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[286], line 2
#       1 plt.figure(figsize = (10,5))
# ----> 2 x= sns.countplot(x = 'director',data = t , order = t['director'].value_counts().index[:10])
#       3 plt.xticks(rotation = 90)
#       4 plt.grid()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2675, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2671     p.plot_data[count_axis] /= len(p.plot_data) / denom
#    2673 aggregator = EstimateAggregator("sum", errorbar=None)
# -> 2675 p.plot_bars(
#    2676     aggregator=aggregator,
#    2677     dodge=dodge,
#    2678     width=width,
#    2679     gap=gap,
#    2680     color=color,
#    2681     fill=fill,
#    2682     capsize=0,
#    2683     err_kws={},
# ...

# %%
print(t.columns)
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
print(t['director'].isna().sum())
# Out:
# 0

# %%
# Remove rows with NaN in the 'director' column
t = t.dropna(subset=['director'])

# Plot the count plot
plt.figure(figsize=(10, 5))
x = sns.countplot(
    x='director',
    data=t,
    order=t['director'].value_counts().index[:10]
)

# Rotate x-axis labels
plt.xticks(rotation=90)

# Add grid
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[292], line 6
#       4 # Plot the count plot
#       5 plt.figure(figsize=(10, 5))
# ----> 6 x = sns.countplot(
#       7     x='director',
#       8     data=t,
#       9     order=t['director'].value_counts().index[:10]
#      10 )
#      12 # Rotate x-axis labels
#      13 plt.xticks(rotation=90)
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2675, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2671     p.plot_data[count_axis] /= len(p.plot_data) / denom
#    2673 aggregator = EstimateAggregator("sum", errorbar=None)
# -> 2675 p.plot_bars(
#    2676     aggregator=aggregator,
#    2677     dodge=dodge,
#    2678     width=width,
#    2679     gap=gap,
# ...

# %%
t = t.drop_duplicates()

# %%
t['director'] = t['director'].str.lower()

# %%
order = t['director'].value_counts().index[:10]
print(order)  # Verify the top 10 unique values
# Out:
# Index(['alastair fothergill', 'ken burns', 'jung-ah im',
#        'gautham vasudev menon', 'iginio straffi', 'hsu fu-chun', 'stan lathan',
#        'joe berlinger', 'shin won-ho', 'lynn novick'],
#       dtype='object', name='director')

# %%
order = t['director'].value_counts().reset_index()['index'][:10]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'index'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[300], line 1
# ----> 1 order = t['director'].value_counts().reset_index()['index'][:10]
#
# ...

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
s = data.copy()

# %%
s
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
ss = data[data['type'] == 'Movie']

# %%
ss
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %%
ss['director'] = ss['director'].str.split(',').explode('director')
ss['director'] = ss['director'].str.lstrip()
ss.replace('',np.nan,inplace = True)
ss.dropna(subset = ['director'],inplace = True)

# %%
ss
# Out:
#      show_id   type                             title                director  \
# 0         s1  Movie              Dick Johnson Is Dead         Kirsten Johnson
# 6         s7  Movie  My Little Pony: A New Generation           Bruno Garotti
# 7         s8  Movie                           Sankofa  Pedro de Echave García
# 9        s10  Movie                      The Starling              Adam Salky
# 12       s13  Movie                      Je Suis Karl           Stanley Moore
# ...      ...    ...                               ...                     ...
# 8801   s8802  Movie                           Zinzana                     NaN
# 8802   s8803  Movie                            Zodiac                     NaN
# 8804   s8805  Movie                        Zombieland                     NaN
# 8805   s8806  Movie                              Zoom                     NaN
# 8806   s8807  Movie                            Zubaan                     NaN
#
# ...

# %%
ss['director'].value_counts()
# Out:
# director
# Rajiv Chilaka      15
# Raúl Campos        13
# Jay Karas          11
# Martin Scorsese    11
# Jan Suter          10
#                    ..
# Farhan Alam         1
# Lea Glob            1
# Ahmed Zain          1
# Rémy Four           1
# Mozez Singh         1
# Name: count, Length: 3434, dtype: int64

# %%
da = ss.assign(country = ss['country'].str.split(',')).explode('country')

# %%
da
# Out:
#      show_id   type                             title                director  \
# 0         s1  Movie              Dick Johnson Is Dead         Kirsten Johnson
# 6         s7  Movie  My Little Pony: A New Generation           Bruno Garotti
# 7         s8  Movie                           Sankofa  Pedro de Echave García
# 7         s8  Movie                           Sankofa  Pedro de Echave García
# 7         s8  Movie                           Sankofa  Pedro de Echave García
# ...      ...    ...                               ...                     ...
# 8801   s8802  Movie                           Zinzana                     NaN
# 8802   s8803  Movie                            Zodiac                     NaN
# 8804   s8805  Movie                        Zombieland                     NaN
# 8805   s8806  Movie                              Zoom                     NaN
# 8806   s8807  Movie                            Zubaan                     NaN
#
# ...

# %%
ind = da[da['country'] == 'India']

# %%
da['country']
# Out:
# 0       United States
# 6                 NaN
# 7       United States
# 7               Ghana
# 7        Burkina Faso
#             ...
# 8801           Jordan
# 8802    United States
# 8804    United States
# 8805    United States
# 8806            India
# Name: country, Length: 7819, dtype: object

# %%
ind
# Out:
#      show_id   type                  title          director  \
# 24       s25  Movie                  Jeans  Steven Spielberg
# 105     s106  Movie       Angamaly Diaries        Jim Henson
# 114     s115  Movie                 Anjaam      Sergio Leone
# 116     s117  Movie                 Dhanak    Todd Wilderman
# 118     s119  Movie                Gurgaon    Peter Farrelly
# ...      ...    ...                    ...               ...
# 8772   s8773  Movie  Yamla Pagla Deewana 2               NaN
# 8773   s8774  Movie    Yanda Kartavya Aahe               NaN
# 8798   s8799  Movie               Zed Plus               NaN
# 8799   s8800  Movie                  Zenda               NaN
# 8806   s8807  Movie                 Zubaan               NaN
#
#                                                    cast country date_added  \
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...   India 2021-09-21
# 105   Antony Varghese, Reshma Rajan, Binny Rinky Ben...   India 2021-09-05
# ...

# %%
ind.groupby('director')['title'].count().sort_values(ascending = False).head(10)
# Out:
# director
# Ozan Açıktan        4
# Joey So             4
# Priyadarshan        3
# Asit Mohapatra      3
# Rajiv Chilaka       3
# Raúl Campos         3
# Larry Latham        2
# Ismail Farouk       2
# Don Michael Paul    2
# Marcus Raboy        2
# Name: title, dtype: int64

# %%
top_ds = ind['director'].value_counts().nlargest(10).index

# %%
top_ds
# Out:
# Index(['Joey So', 'Ozan Açıktan', 'Priyadarshan', 'Rajiv Chilaka',
#        'Asit Mohapatra', 'Raúl Campos', 'Dallas Jackson', 'Kenneth Gyang',
#        'Sam Mendes', 'Fernando Ayllón'],
#       dtype='object', name='director')

# %%
f_data = ind[ind['director'].isin(top_ds)]
plt.figure(figsize = (10,5))
sns.countplot(x = 'director',data = f_data ,order = top_ds)
plt.xticks(rotation = 90)
plt.grid(True)
plt.show()

# %%
# Out:
#      show_id   type                               title         director  \
# 259     s260  Movie                              Pahuna    Kenneth Gyang
# 301     s302  Movie                     Chennai Express    Rajiv Chilaka
# 518     s519  Movie        Har Kisse Ke Hisse: Kaamyaab    Kenneth Gyang
# 1376   s1377  Movie           Kilometers and Kilometers   Dallas Jackson
# 1388   s1389  Movie                     The White Tiger     Ozan Açıktan
# 1858   s1859  Movie                                Fida          Joey So
# 2015   s2016  Movie                         Aapla Manus          Joey So
# 2016   s2017  Movie       Ani... Dr. Kashinath Ghanekar          Joey So
# 2017   s2018  Movie  Bhai: Vyakti Ki Valli - Poorvardha          Joey So
# 2392   s2393  Movie                               Axone     Ozan Açıktan
# 2728   s2729  Movie           Humpty Sharma Ki Dulhania   Dallas Jackson
# 2734   s2735  Movie                  Kuch Kuch Hota Hai  Fernando Ayllón
# ...

# %%
movie = data[data['type'] == 'Movie']

# %%
movie
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %%
year = movie[(movie['release_year'] >= 1990) & (movie['release_year'] <= 2000)]

# %%
year
# Out:
#      show_id   type               title          director  \
# 7         s8  Movie             Sankofa      Haile Gerima
# 22       s23  Movie     Avvai Shanmughi    K.S. Ravikumar
# 24       s25  Movie               Jeans        S. Shankar
# 26       s27  Movie      Minsara Kanavu       Rajiv Menon
# 114     s115  Movie              Anjaam      Rahul Rawail
# ...      ...    ...                 ...               ...
# 8629   s8630  Movie            Trimurti       Mukul Anand
# 8722   s8723  Movie   What Lies Beneath   Robert Zemeckis
# 8729   s8730  Movie  Where the Money Is   Marek Kanievska
# 8742   s8743  Movie      Wild Wild West  Barry Sonnenfeld
# 8764   s8765  Movie          Wyatt Earp   Lawrence Kasdan
#
#                                                    cast  \
# 7     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 22    Kamal Hassan, Meena, Gemini Ganesan, Heera Raj...
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...
# ...

# %%
year['rating'].value_counts()
# Out:
# rating
# Adults only                                  83
# Teens(13+)                                   65
# Young Adults(16+)                            50
# Adults(18+)                                  30
# Older Kids(7+)                               22
# Older Kids(7+)Parental Guidance Suggested    13
# Kids(All)                                     7
# Kids(All)Suitable for all ages                2
# Adults(18+) NotRated                          2
# Name: count, dtype: int64

# %%
plt.figure(figsize = (15,5))
year['rating'].value_counts().plot.pie(explode = (0,0,0,0,0,0.1,0.2,0.3,0.4),startangle = 90, autopct = '%1.1f%%')
plt.title('rating vs given year',loc = 'left')
plt.show()

# %%
top_cast = data.copy()

# %%
top_cast = top_cast[top_cast['cast'].str.split(',').explode('cast')]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[432], line 1
# ----> 1 top_cast = top_cast[top_cast['cast'].str.split(',').explode('cast')]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
# ...

# %%
top_cast
# Out:
# 0                    Ama Qamata
# 1                   Khosi Ngema
# 2                 Gail Mabalane
# 3                Thabang Molaba
# 4              Dillon Windvogel
#                   ...
# 64121          Manish Chaudhary
# 64122              Meghna Malik
# 64123             Malkeet Rauni
# 64124            Anita Shabdish
# 64125     Chittaranjan Tripathy
# Name: cast, Length: 64126, dtype: object

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
top_cast
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
top_cast = data.copy()

# %%
top_cast['cast'] = top_cast['cast'].str.split(',')
top_cast = top_cast.explode('cast')

# %%
top_cast.dropna(subset=['cast'],inplace = True)

# %%
top_cast.groupby('cast')['title'].count().sort_values(ascending = False)
# Out:
# cast
#  Anupam Kher         39
#  Rupa Bhimani        31
#  Takahiro Sakurai    30
#  Julie Tejwani       28
#  Om Puri             27
#                      ..
#  João Côrtes          1
#  João Assunção        1
#  Joziah Lagonoy       1
#  Jozef Gjura          1
# Ṣọpẹ́ Dìrísù          1
# Name: title, Length: 39296, dtype: int64

# %%
top_cast
# Out:
#      show_id     type          title     director                    cast  \
# 1         s2  TV Show  Blood & Water          NaN              Ama Qamata
# 1         s2  TV Show  Blood & Water          NaN             Khosi Ngema
# 1         s2  TV Show  Blood & Water          NaN           Gail Mabalane
# 1         s2  TV Show  Blood & Water          NaN          Thabang Molaba
# 1         s2  TV Show  Blood & Water          NaN        Dillon Windvogel
# ...      ...      ...            ...          ...                     ...
# 8806   s8807    Movie         Zubaan  Mozez Singh        Manish Chaudhary
# 8806   s8807    Movie         Zubaan  Mozez Singh            Meghna Malik
# 8806   s8807    Movie         Zubaan  Mozez Singh           Malkeet Rauni
# 8806   s8807    Movie         Zubaan  Mozez Singh          Anita Shabdish
# 8806   s8807    Movie         Zubaan  Mozez Singh   Chittaranjan Tripathy
#
#            country date_added  release_year             rating   duration  \
# ...

# %%
plt.figure(figsize =(15,5))
sns.countplot(x = 'cast', data = top_cast, order = top_cast['cast'].value_counts().index[:10])

plt.xticks = 90
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[492], line 2
#       1 plt.figure(figsize =(15,5))
# ----> 2 sns.countplot(x = 'cast', data = top_cast, order = top_cast['cast'].value_counts().index[:10])
#       4 plt.xticks = 90
#       5 plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2675, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2671     p.plot_data[count_axis] /= len(p.plot_data) / denom
#    2673 aggregator = EstimateAggregator("sum", errorbar=None)
# -> 2675 p.plot_bars(
#    2676     aggregator=aggregator,
#    2677     dodge=dodge,
#    2678     width=width,
#    2679     gap=gap,
#    2680     color=color,
#    2681     fill=fill,
#    2682     capsize=0,
#    2683     err_kws={},
# ...

# %%
top_cast['cast'].value_counts()
# Out:
# cast
# Anupam Kher              39
# Rupa Bhimani             31
# Takahiro Sakurai         30
# Julie Tejwani            28
# Om Puri                  27
#                          ..
# Vedika                    1
# Tedros Teclebrhan         1
# Maryam Zaree              1
# Melanie Straub            1
# Chittaranjan Tripathy     1
# Name: count, Length: 39296, dtype: int64

# %%
top_cast = top_cast.reset_index().drop('index',axis = 1,)

# %%
top_cast
# Out:
#       show_id     type          title     director                    cast  \
# 0          s2  TV Show  Blood & Water          NaN              Ama Qamata
# 1          s2  TV Show  Blood & Water          NaN             Khosi Ngema
# 2          s2  TV Show  Blood & Water          NaN           Gail Mabalane
# 3          s2  TV Show  Blood & Water          NaN          Thabang Molaba
# 4          s2  TV Show  Blood & Water          NaN        Dillon Windvogel
# ...       ...      ...            ...          ...                     ...
# 64121   s8807    Movie         Zubaan  Mozez Singh        Manish Chaudhary
# 64122   s8807    Movie         Zubaan  Mozez Singh            Meghna Malik
# 64123   s8807    Movie         Zubaan  Mozez Singh           Malkeet Rauni
# 64124   s8807    Movie         Zubaan  Mozez Singh          Anita Shabdish
# 64125   s8807    Movie         Zubaan  Mozez Singh   Chittaranjan Tripathy
#
# ...

# %%
plt.figure(figsize =(15,5))
sns.countplot(x = 'cast', data = top_cast, order = top_cast['cast'].value_counts().index[:10])

plt.xticks = 90
plt.show()

# %%
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data['month'] = data['date_added'].dt.strftime('%b')

# %%
data.groupby('month')['title'].count().to_frame().reset_index()
# Out:
#    month  title
# 0    Apr    759
# 1    Aug    749
# 2    Dec    797
# 3    Feb    557
# 4    Jan    727
# 5    Jul    819
# 6    Jun    724
# 7    Mar    734
# 8    May    626
# 9    Nov    697
# 10   Oct    755
# 11   Sep    765

# %%
plt.figure(figsize=(15,5))
sns.countplot(x = 'month',data = data , order = data['month'].value_counts().index[:10])
plt.xticks = 90
plt.show()
